# %%
import os
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model
load_dotenv()

os.environ["GEMINI_API_KEY"] = os.getenv("GEMINI_API_KEY")

model = init_chat_model("google_genai:gemini-2.5-flash")

response = model.invoke("How to use gemini api key for llm integration?")
response.content
# Out:
# 'Using your Gemini API key for LLM integration, primarily with Python, involves a few straightforward steps. Google provides a robust client library (`google-generativeai`) that makes this process very smooth.\n\nHere\'s a step-by-step guide:\n\n---\n\n## 1. Prerequisites\n\nBefore you start, make sure you have:\n\n*   **A Google Cloud Project:** You need a project to enable the Gemini API.\n*   **A Gemini API Key:** You can generate this from Google AI Studio or the Google Cloud Console (under "APIs & Services" > "Credentials"). Keep this key secure!\n*   **Python installed:** Version 3.8 or higher is recommended.\n*   **An IDE or text editor:** (e.g., VS Code, PyCharm)\n\n---\n\n## 2. Set Up Your Python Environment\n\nIt\'s good practice to use a virtual environment for your Python projects.\n\n1.  **Create a virtual environment:**\n    ```bash\n    python -m venv .venv\n    ```\n2.  **Activate the virtual environment:**\n    *   On macOS/Linux:\n        ```bash\n        source .venv/bin/activate\n        ```\n    *   On Windows:\n        ```bash\n        .venv\\Scripts\\activate\n        ```\n3.  **Install the Google Generative AI SDK:**\n    ```bash\n    pip install google-generativeai python-dotenv Pillow\n    ```\n    *   `google-generativeai`: The official SDK.\n    *   `python-dotenv`: For securely loading your API key from a `.env` file.\n    *   `Pillow`: (Optional) Useful for handling images if you plan to use multimodal models like `gemini-pro-vision`.\n\n---\n\n## 3. Securely Load Your API Key\n\n**NEVER hardcode your API key directly into your script.** The safest way is to use environment variables.\n\n1.  **Create a `.env` file** in the root directory of your project (the same directory where your Python script will be).\n    ```\n    GEMINI_API_KEY="YOUR_API_KEY_HERE"\n    ```\n    Replace `"YOUR_API_KEY_HERE"` with your actual Gemini API key.\n\n2.  **Add `.env` to your `.gitignore` file** if you\'re using Git, to prevent accidentally committing your key.\n    ```\n    .env\n    ```\n\n---\n\n## 4. Initialize the Gemini Model in Python\n\nNow you can write your Python script. Let\'s create a file named `gemini_integration.py`.\n\n```python\nimport os\nimport google.generativeai as genai\nfrom dotenv import load_dotenv\n\n# 1. Load environment variables from .env file\nload_dotenv()\n\n# 2. Configure the API key\n# Retrieve the API key from environment variables\nGEMINI_API_KEY = os.getenv("GEMINI_API_KEY")\n\nif not GEMINI_API_KEY:\n    raise ValueError("GEMINI_API_KEY not found in environment variables. Please set it in a .env file or directly.")\n\ngenai.configure(api_key=GEMINI_API_KEY)\n\n# 3. Choose a model\n# \'gemini-pro\' for text-only interactions\n# \'gemini-pro-vision\' for multimodal interactions (text and images)\nmodel = genai.GenerativeModel(\'gemini-pro\')\n\nprint("Gemini model initialized successfully!")\n\n# --- You\'re now ready to use the model! ---\n```\n\n---\n\n## 5. Make API Calls (Examples)\n\nHere are common ways to interact with the Gemini model:\n\n### A. Simple Text Generation\n\n```python\n# ... (previous setup code) ...\n\n# 4. Make a simple text generation request\ntry:\n    prompt = "Tell me a short, imaginative story about a robot who discovers art."\n    print(f"\\n--- Prompt ---\\n{prompt}\\n")\n\n    response = model.generate_content(prompt)\n\n    print("\\n--- Response ---\\n")\n    print(response.text)\n\nexcept Exception as e:\n    print(f"An error occurred: {e}")\n```\n\n### B. Multi-turn Conversations (Chat)\n\nGemini can maintain a conversational context.\n\n```python\n# ... (previous setup code) ...\n\n# 5. Start a multi-turn conversation\nchat = model.start_chat(history=[]) # Initialize with an empty history\n\nprint("\\n--- Starting a Chat ---")\n\n# First turn\nchat_prompt1 = "Hello! What\'s your name?"\nprint(f"User: {chat_prompt1}")\nresponse1 = chat.send_message(chat_prompt1)\nprint(f"Gemini: {response1.text}")\n\n# Second turn, building on the previous cont ...

# %%
from langchain_openai import ChatOpenAI
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_groq import ChatGroq
